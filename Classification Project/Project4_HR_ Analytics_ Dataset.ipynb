# %%
#Import basic library for EDA
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#import HR_Employee_Attrition.csv file
df=pd.read_csv('HR_Employee_Attrition.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# Finding:
#     1. No missing value in any features.
#     2. 1470 row with 35 columns in this dataset.
#     3. 26 features is int type and 9 features is object type.
#     4. Many features according to data or hypothesis like categorical features.
#     5. For understanding of Some categorical features done by exploring data coulumns.
#     6. some feature are not reqired than we will drop during cleansing of data.

# %% [markdown]
# ### Check Missing value

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# ## Summary statistics of numerical features

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# Observation:
#     1. Light shades are highly correlated .
#     2. Drop some columns which are not reqired.

# %%
df.hist(figsize=(20,20))
plt.show()

# %% [markdown]
# Oservation:
#     1. Several distributions are right-skewed (e.g. MonthlyIncome DistanceFromHome, YearsAtCompany).
#     2. Age distribution is a slightly right-skewed normal distribution with the bulk of the staff between 25 and 45 years old.
#     3. EmployeeCount and StandardHours are constant values for all employees. They're likely to be redundant features.
#     4. Employee Number is likely to be a unique identifier for employees given the feature's quasi-uniform distribution.

# %%
df.drop(columns=['EmployeeNumber','Over18','EmployeeCount','StandardHours','StockOptionLevel','RelationshipSatisfaction','DailyRate','HourlyRate'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  Gender  JobInvolvement  \
# 0          2  Life Sciences                        2  Female               3
# 1          1  Life Sciences                        3    Male               2
# 2          2          Other                        4    Male               2
# 3          4  Life Sciences                        4  Female               3
# 4          1        Medical                        1    Male               3
#
# ...

# %% [markdown]
# ### Exploring Data variable

# %%
for i in df:
    print(i,'\n',df[i].unique(),'\n\n')
# Out:
# Age
#  [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
#
#
# Attrition
#  ['Yes' 'No']
#
#
# BusinessTravel
#  ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
#
#
# Department
#  ['Sales' 'Research & Development' 'Human Resources']
#
#
# DistanceFromHome
#  [ 1  8  2  3 24 23 27 16 15 26 19 21  5 11  9  7  6 10  4 25 12 18 29 22
#  14 20 28 17 13]
#
#
# Education
#  [2 1 4 3 5]
#
#
# EducationField
#  ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
#
#
# EnvironmentSatisfaction
#  [2 3 4 1]
#
#
# Gender
#  ['Female' 'Male']
#
#
# JobInvolvement
#  [3 2 4 1]
#
#
# JobLevel
#  [2 1 3 4 5]
#
#
# JobRole
#  ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
#
#
# JobSatisfaction
#  [4 2 3 1]
#
#
# MaritalStatus
# ...

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Feature distribution by target attribute  ‘Attrition’ by using employee’s personal history.

# %%
#Start with Target Variable: Attrition
print(df['Attrition'].value_counts())
sns.countplot(df['Attrition'])
plt.title('Attrition of Emolyee')
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# Text(0.5, 1.0, 'Attrition of Emolyee')

# %% [markdown]
# Finding:
#     1.The percentage of Current Employees is more than Ex-employees in this dataset.
#     2. the percentage of Current Employees is 83.9% and of Ex-employees is 16.1%. Hence, this is an imbalanced class problem.

# %%
# Lets draw histogram for Age 
plt.hist(x='Age',bins=10,data=df)
plt.show()

# %% [markdown]
# Finding: Age between 30 to 40 number of empolyee maximum in this dataset.

# %%
#Emplyee number with respect gender
print(df['Gender'].value_counts())
sns.countplot(df['Gender'])
plt.title('Total number of employee according to gender')
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64
# Text(0.5, 1.0, 'Total number of employee according to gender')

# %%
#Gender Vs Attrition
sns.countplot(x='Gender',hue='Attrition',data=df)
plt.title('Attrition rate acoording to gender')
# Out:
# Text(0.5, 1.0, 'Attrition rate acoording to gender')

# %% [markdown]
# Observation: Gender distribution shows that the dataset features a higher relative proportion of male ex-employees than
#     female ex-employees

# %%
#Empolyee number according to overtime
print(df['OverTime'].value_counts())
sns.countplot(df['OverTime'])
plt.title('Empolyee number according to overtime OverTime')
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64
# Text(0.5, 1.0, 'Empolyee number according to overtime OverTime')

# %%
#overtime vs Attrition
sns.countplot(x='OverTime',data=df, hue='Attrition')
plt.title('Attrition rate acoording to OverTime')
# Out:
# Text(0.5, 1.0, 'Attrition rate acoording to OverTime')

# %% [markdown]
# Observation: Some employees have overtime commitments. The data clearly show that there is significant larger portion of employees with OT that have left the company.

# %%
#Total number of employee according to BusinessTravel
print(df['BusinessTravel'].value_counts())
sns.countplot(df['BusinessTravel'])
plt.title('Total number of employee according to BusinessTravel')
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# Text(0.5, 1.0, 'Total number of employee according to BusinessTravel')

# %%
#BusinessTravel vs Attrition
sns.countplot(x='BusinessTravel',data=df, hue='Attrition')
plt.title('Attrition rate acoording to BusinessTravel')
# Out:
# Text(0.5, 1.0, 'Attrition rate acoording to BusinessTravel')

# %% [markdown]
# Observation: More Attrition travel_rarely and current empoyee also from travel_rarely.

# %%
#Total number of employee according to JobSatisfaction
print(df['JobSatisfaction'].value_counts())
sns.countplot(df['JobSatisfaction'])
plt.title('Total number of employee according to JobSatisfaction')
# Out:
# 4    459
# 3    442
# 1    289
# 2    280
# Name: JobSatisfaction, dtype: int64
# Text(0.5, 1.0, 'Total number of employee according to JobSatisfaction')

# %%
#JobSatisfaction vs Attrition
sns.countplot(x='JobSatisfaction',hue='Attrition',data=df)

# %% [markdown]
# ### Feature distribution by target attribute ‘Attrition’ by using employee’s professional history.

# %%
# for attrtion of employee's
att_yes=df[df['Attrition']=='Yes']

# %%
plt.figure(figsize=(12,5))
sns.barplot(x='EducationField', y='Education', hue='Attrition', data=att_yes)

# %%
#Total number of employee's according to MaritalStatus
print(df['MaritalStatus'].value_counts())
sns.countplot(df['MaritalStatus'])
plt.title('Total number of employees according to MaritalStatus')
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64
# Text(0.5, 1.0, 'Total number of employees according to MaritalStatus')

# %%
sns.countplot(x='MaritalStatus',data=att_yes,hue='Gender')

# %% [markdown]
# Observation: The dataset features three marital status: Married (673 employees), Single (470 employees), Divorced (327 employees). Single employees show the largest proportion of leavers at 25%.

# %%
sns.countplot(x='NumCompaniesWorked',data=att_yes)

# %%
sns.countplot(x='TrainingTimesLastYear',data=att_yes)

# %%
sns.countplot(x='YearsWithCurrManager',data=att_yes)

# %%
sns.scatterplot(x='PercentSalaryHike',y='YearsAtCompany', data=att_yes, hue='PerformanceRating')

# %%
sns.catplot(x='YearsInCurrentRole',y='YearsAtCompany',data=df,hue='Attrition',kind='point')

# %%
#Empolyee number according to JobRole
plt.figure(figsize=(20,8))
print(df['JobRole'].value_counts())
sns.countplot(df['JobRole'])
plt.title('Empolyee number according to JobRole')
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64
# Text(0.5, 1.0, 'Empolyee number according to JobRole')

# %% [markdown]
# Finding: Several Job Roles are listed in the dataset: Sales Executive, Research Scientist, Laboratory Technician, Manufacturing Director, Healthcare Representative, Manager, Sales Representative, Research Director, Human Resources.

# %%
#JobRole vs Attrition
plt.figure(figsize=(20,8))
sns.countplot(x='JobRole',hue='Attrition',data=att_yes)

# %% [markdown]
# EDA Concluding Remarks:-
#
#
# 1.The dataset does not feature any missing or erroneous data values, and all features are of the correct data type.
#
# 2. The strongest positive correlations with the target features are: Performance Rating, Monthly Rate,Num Companies
#     Worked, Distance From Home.
#
# 3. The strongest negative correlations with the target features are: Total Working Years, Job Level, Years In Current Role,
#     and Monthly Income.
#
# 4. The dataset is imbalanced with the majoriy of observations describing Currently Active Employees.
#
# 5. Single employees show the largest proportion of leavers, compared to Married and Divorced counterparts.
#
# 6. About 10% of leavers left when they reach their 2-year anniversary at the company.
#
# 7. People who live further away from their work show higher proportion of leavers compared to their counterparts.
#
# 8. People who travel frequently show higher proportion of leavers compared to their counterparts.
#
# 9. People who have to work overtime show higher proportion of leavers compared to their counterparts.
#
# 10. Employees that have already worked at several companies previously (already “bounced” between workplaces)
# show higher proportion of leavers compared to their counterparts.

# %% [markdown]
# ### Check skewness

# %%
df.skew()
# Out:
# Age                        0.413286
# DistanceFromHome           0.958118
# Education                 -0.289681
# EnvironmentSatisfaction   -0.321654
# JobInvolvement            -0.498419
# JobLevel                   1.025401
# JobSatisfaction           -0.329672
# MonthlyIncome              1.369817
# MonthlyRate                0.018578
# NumCompaniesWorked         1.026471
# PercentSalaryHike          0.821128
# PerformanceRating          1.921883
# TotalWorkingYears          1.117172
# TrainingTimesLastYear      0.553124
# WorkLifeBalance           -0.552480
# YearsAtCompany             1.764529
# YearsInCurrentRole         0.917363
# YearsSinceLastPromotion    1.984290
# YearsWithCurrManager       0.833451
# dtype: float64

# %%
#Lets treat the skewness for numerical features
import numpy as np
df.skew()
for col in df.skew().index:
    if col in df.describe().columns:
        if df.skew().loc[col]>0.5:
            df[col]=np.sqrt(df[col])
        if df.skew().loc[col]<-0.5:
            df[col]=np.cbrt(df[col])

# %%
#Again check skewness
df.skew()
# Out:
# Age                        0.413286
# DistanceFromHome           0.398114
# Education                 -0.289681
# EnvironmentSatisfaction   -0.321654
# JobInvolvement            -0.498419
# JobLevel                   0.593923
# JobSatisfaction           -0.329672
# MonthlyIncome              0.861960
# MonthlyRate                0.018578
# NumCompaniesWorked         0.031303
# PercentSalaryHike          0.655412
# PerformanceRating          1.921883
# TotalWorkingYears          0.176358
# TrainingTimesLastYear     -4.082699
# WorkLifeBalance           -1.202646
# YearsAtCompany             0.426835
# YearsInCurrentRole        -0.254344
# YearsSinceLastPromotion    0.739126
# YearsWithCurrManager      -0.254611
# dtype: float64

# %% [markdown]
# ## Plotting outliers

# %%
for i in df.describe().columns:
    sns.boxplot(df[i])
    plt.show()

# %% [markdown]
# ### Removing outliers

# %%
df1=df.copy()
df1.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales          1.000000
# 1   49        No  Travel_Frequently  Research & Development          2.828427
# 2   37       Yes      Travel_Rarely  Research & Development          1.414214
# 3   33        No  Travel_Frequently  Research & Development          1.732051
# 4   27        No      Travel_Rarely  Research & Development          1.414214
#
#    Education EducationField  EnvironmentSatisfaction  Gender  JobInvolvement  \
# 0          2  Life Sciences                        2  Female               3
# 1          1  Life Sciences                        3    Male               2
# 2          2          Other                        4    Male               2
# 3          4  Life Sciences                        4  Female               3
# 4          1        Medical                        1    Male               3
#
# ...

# %%
df1.shape
# Out:
# (1470, 27)

# %%
from scipy.stats import zscore
z=np.abs(zscore(df1.describe()))
z
# Out:
# array([[2.64453899, 2.64574102, 2.64574197, 2.64574481, 2.64574546,
#         2.64574981, 2.64574482, 2.63867304, 1.24508058, 2.64574755,
#         2.64574267, 2.64574956, 2.64573414, 2.64575009, 2.64575027,
#         2.6457347 , 2.64574384, 2.64574403, 2.64574425],
#        [0.37015578, 0.3777154 , 0.37753528, 0.37759927, 0.37717838,
#         0.37779185, 0.37759013, 0.36415779, 0.29660227, 0.37788664,
#         0.3770734 , 0.37748928, 0.37739021, 0.37745854, 0.3775297 ,
#         0.37795417, 0.37808527, 0.37837963, 0.37811827],
#        [0.428613  , 0.38059649, 0.38142751, 0.38095519, 0.3813367 ,
#         0.37989743, 0.38093996, 0.47105295, 0.56712179, 0.37910135,
#         0.38412285, 0.3809415 , 0.38149526, 0.37931602, 0.38011653,
#         0.380626  , 0.37960803, 0.37835588, 0.37954256],
#        [0.40996491, 0.38127187, 0.38147731, 0.38114699, 0.38074245,
#         0.37859305, 0.38115187, 0.45978595, 1.17017578, 0.38080491,
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %% [markdown]
# Finding: No any row detect as Outliers

# %% [markdown]
# # Machine Learning Alogorithm

# %% [markdown]
# Pre-processing Pipeline

# %%
#Splitting x and y
x=df1.drop(columns=['Attrition'])
x.head()
# Out:
#    Age     BusinessTravel              Department  DistanceFromHome  \
# 0   41      Travel_Rarely                   Sales          1.000000
# 1   49  Travel_Frequently  Research & Development          2.828427
# 2   37      Travel_Rarely  Research & Development          1.414214
# 3   33  Travel_Frequently  Research & Development          1.732051
# 4   27      Travel_Rarely  Research & Development          1.414214
#
#    Education EducationField  EnvironmentSatisfaction  Gender  JobInvolvement  \
# 0          2  Life Sciences                        2  Female               3
# 1          1  Life Sciences                        3    Male               2
# 2          2          Other                        4    Male               2
# 3          4  Life Sciences                        4  Female               3
# 4          1        Medical                        1    Male               3
#
#    JobLevel  ... OverTime  PercentSalaryHike PerformanceRating  \
# ...

# %%
y=df1['Attrition']
y.head()
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# 4     No
# Name: Attrition, dtype: object

# %%
x.shape
# Out:
# (1470, 26)

# %%
#Encoding
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
#By using label encoder transform Gender and OverTime feature becuse in this feature only 2 value either 0 either 1
x['Gender']=le.fit_transform(x['Gender'])

# %%
x['OverTime']=le.fit_transform(x['OverTime'])

# %%
x.head()
# Out:
#    Age     BusinessTravel              Department  DistanceFromHome  \
# 0   41      Travel_Rarely                   Sales          1.000000
# 1   49  Travel_Frequently  Research & Development          2.828427
# 2   37      Travel_Rarely  Research & Development          1.414214
# 3   33  Travel_Frequently  Research & Development          1.732051
# 4   27      Travel_Rarely  Research & Development          1.414214
#
#    Education EducationField  EnvironmentSatisfaction  Gender  JobInvolvement  \
# 0          2  Life Sciences                        2       0               3
# 1          1  Life Sciences                        3       1               2
# 2          2          Other                        4       1               2
# 3          4  Life Sciences                        4       0               3
# 4          1        Medical                        1       1               3
#
#    JobLevel  ... OverTime  PercentSalaryHike PerformanceRating  \
# ...

# %%
# Converting remaining categorical variables in x using get_dummies
x=pd.get_dummies(x)
x.shape
# Out:
# (1470, 45)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)

# %%
y=le.fit_transform(y)
y.shape
# Out:
# (1470,)

# %%
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42,stratify=y)

# %%
print(x_train.shape,x_test.shape)
# Out:
# (1029, 45) (441, 45)

# %%
print(y_train.shape,y_test.shape)
# Out:
# (1029,) (441,)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier

# %%
from sklearn.metrics import accuracy_score,roc_auc_score,confusion_matrix
from sklearn.model_selection import GridSearchCV,cross_val_score

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier

knn=KNeighborsClassifier()
neighbors={'n_neighbors':range(1,30)}
bknn=GridSearchCV(knn,neighbors)
bknn.fit(x_train,y_train)
bknn.best_params_
# Out:
# {'n_neighbors': 5}

# %%
KNN=KNeighborsClassifier(n_neighbors=5)

# %%
#Support Vector Classifier
from sklearn.svm import SVC

svc=SVC()
svc_parameters={'kernel':['linear','sigmoid','poly','rbf'],'C':[1,10]}
bsvc=GridSearchCV(svc,svc_parameters)
bsvc.fit(x_train,y_train)
bsvc.best_params_
# Out:
# {'C': 1, 'kernel': 'linear'}

# %%
SV=SVC(kernel='linear',C=1)

# %%
#Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier

criterion = {'criterion':['gini','entropy']}
dtc=DecisionTreeClassifier(random_state=42)
bdtc=GridSearchCV(dtc,criterion)
bdtc.fit(x_train,y_train)
bdtc.best_params_
# Out:
# {'criterion': 'entropy'}

# %%
DTC=DecisionTreeClassifier(criterion='entropy',random_state=42)

# %%
#Random Forest Classifer
from sklearn.ensemble import RandomForestClassifier

parameters = {'n_estimators':range(100,200,300)}
rf=RandomForestClassifier(random_state=42)
brf=GridSearchCV(rf,parameters)
brf.fit(x_train,y_train)
brf.best_params_
# Out:
# {'n_estimators': 100}

# %%
RFC=RandomForestClassifier(n_estimators=100,random_state=42)

# %%
#Gradient Boosting Classifier

GBC=GradientBoostingClassifier(n_estimators=250)

# %%
#Extra Trees Classifier

ETC=ExtraTreesClassifier(n_estimators=250)

# %%
#AdaBoost Classifier

ABC=AdaBoostClassifier(n_estimators=50)

# %%
#Bagging Classifier

BC=BaggingClassifier(n_estimators=250)

# %%
KNN=KNeighborsClassifier(n_neighbors=5)
SV=SVC(kernel='linear',C=1)
LR=LogisticRegression()
DT=DecisionTreeClassifier(criterion='entropy',random_state=42)
GNB=GaussianNB()
RFC=RandomForestClassifier(n_estimators=100,random_state=42)
GBC=GradientBoostingClassifier(n_estimators=250)
ETC=ExtraTreesClassifier(n_estimators=250)
ABC=AdaBoostClassifier(n_estimators=50)
BC=BaggingClassifier(n_estimators=250)

# %%
models=[]
models.append(('KNeighborsClassifier',KNN))
models.append(('SVC',SV))
models.append(('LogisticRegression',LR))
models.append(('DecisionTreeClassifier',DT))
models.append(('GaussianNB',GNB))
models.append(('RandomForestClassifier',RFC))
models.append(('GradientBoostingClassifier',GBC))
models.append(('ExtraTreesClassifier',ETC))
models.append(('AdaBoostClassifier',ABC))
models.append(('BaggingClassifier',BC))

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,roc_curve,auc

# %%
Model=[]
score=[]
CVS=[]
rocscore=[]
for name,model in models:
    print('************',name,'**********')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print('Accuracy_score=',AS)
    score.append(AS*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring='accuracy').mean()
    print('Cross_Val_Score=',sc)
    CVS.append(sc*100)
    print('\n')
    false_positive_rate,true_positive_rate,threshold=roc_curve(y_test,pre)
    roc_auc= auc(false_positive_rate,true_positive_rate)
    print('roc_auc_score=',roc_auc)
    rocscore.append(roc_auc*100)
    print('\n')
    print('classification_report\n',classification_report(y_test,pre))
    print('\n')
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    plt.plot(false_positive_rate,true_positive_rate,label='AUC = %0.2f'% roc_auc)
    plt.plot([0,1],[0,1],'r--')
    plt.legend(loc='lower right')
    plt.ylabel('True positive Rate')
    plt.xlabel('False Positive Rate')
    print('\n\n')
# Out:
# ************ KNeighborsClassifier **********
#
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')
#
#
# Accuracy_score= 0.8503401360544217
#
#
# Cross_Val_Score= 0.8523809523809524
#
#
# roc_auc_score= 0.5636657784545109
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       370
#            1       0.67      0.14      0.23        71
#
#     accuracy                           0.85       441
#    macro avg       0.76      0.56      0.57       441
# weighted avg       0.83      0.85      0.81       441
#
#
#
# [[365   5]
#  [ 61  10]]
#
#
#
#
#
# ************ SVC **********
#
#
# SVC(C=1, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
# ...

# %%
result = pd.DataFrame({'Model':Model,'Accuracy_score': score,'cross_val_score':CVS,'Roc_auc_curve':rocscore})
result
# Out:
#                         Model  Accuracy_score  cross_val_score  Roc_auc_curve
# 0        KNeighborsClassifier       85.034014        85.238095      56.366578
# 1                         SVC       87.074830        88.639456      66.119147
# 2          LogisticRegression       86.848073        88.503401      65.414922
# 3      DecisionTreeClassifier       76.190476        79.183673      57.356300
# 4                  GaussianNB       69.841270        71.156463      66.661591
# 5      RandomForestClassifier       83.219955        85.850340      54.716407
# 6  GradientBoostingClassifier       84.353741        86.258503      62.221165
# 7        ExtraTreesClassifier       83.900227        86.258503      55.121812
# 8          AdaBoostClassifier       84.580499        87.755102      61.218120
# 9           BaggingClassifier       83.446712        85.918367      57.127903

# %% [markdown]
# Remarke:
#     1. For Attrition output different models output findout.
#     2. LogisticRegression is best model for this dataset.
#     3. By using LogisticRegression achive 86% acuuracy score.

# %%
#save best model

import joblib
from joblib import dump #from joblib import load > to load .pkl file
joblib.dump(LR,'LR_HR_Analytics.pkl')
# Out:
# ['LR_HR_Analytics.pkl']
